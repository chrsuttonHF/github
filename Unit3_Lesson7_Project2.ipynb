# %% [markdown]
# Unit 3 Lesson 7 Project 2

# %% [markdown]
# Descriptive analysis of a CDC diabetes dataset with multiple medical indicators and
# diseases

# %%
import pandas as pd
import numpy as np
import seaborn as sns #viz
import matplotlib.pyplot as plt #viz
# %matplotlib inline
sns.set(color_codes=True)

# %%
df = pd.read_csv('https://raw.githubusercontent.com/niteen11/DataAnalyticsAcademy/master/Python/dataset_diabetes/diabetic_data.csv')

# %%
df.head()
# Out:
#    encounter_id  patient_nbr             race  gender      age weight  \
# 0       2278392      8222157        Caucasian  Female   [0-10)      ?
# 1        149190     55629189        Caucasian  Female  [10-20)      ?
# 2         64410     86047875  AfricanAmerican  Female  [20-30)      ?
# 3        500364     82442376        Caucasian    Male  [30-40)      ?
# 4         16680     42519267        Caucasian    Male  [40-50)      ?
#
#    admission_type_id  discharge_disposition_id  admission_source_id  \
# 0                  6                        25                    1
# 1                  1                         1                    7
# 2                  1                         1                    7
# 3                  1                         1                    7
# 4                  1                         1                    7
#
#    time_in_hospital  ... citoglipton insulin  glyburide-metformin  \
# ...

# %%
df.tail()
# Out:
#         encounter_id  patient_nbr             race  gender      age weight  \
# 101761     443847548    100162476  AfricanAmerican    Male  [70-80)      ?
# 101762     443847782     74694222  AfricanAmerican  Female  [80-90)      ?
# 101763     443854148     41088789        Caucasian    Male  [70-80)      ?
# 101764     443857166     31693671        Caucasian  Female  [80-90)      ?
# 101765     443867222    175429310        Caucasian    Male  [70-80)      ?
#
#         admission_type_id  discharge_disposition_id  admission_source_id  \
# 101761                  1                         3                    7
# 101762                  1                         4                    5
# 101763                  1                         1                    7
# 101764                  2                         3                    7
# 101765                  1                         1                    7
#
#         time_in_hospital  ... citoglipton insulin  glyburide-metformin  \
# ...

# %%
df.shape
# Out:
# (101766, 50)

# %%
df.dtypes
# Out:
# encounter_id                 int64
# patient_nbr                  int64
# race                        object
# gender                      object
# age                         object
# weight                      object
# admission_type_id            int64
# discharge_disposition_id     int64
# admission_source_id          int64
# time_in_hospital             int64
# payer_code                  object
# medical_specialty           object
# num_lab_procedures           int64
# num_procedures               int64
# num_medications              int64
# number_outpatient            int64
# number_emergency             int64
# number_inpatient             int64
# diag_1                      object
# diag_2                      object
# diag_3                      object
# number_diagnoses             int64
# max_glu_serum               object
# A1Cresult                   object
# metformin                   object
# repaglinide                 object
# nateglinide                 object
# ...

# %%
df.describe()
# Out:
#        encounter_id   patient_nbr  admission_type_id  \
# count  1.017660e+05  1.017660e+05      101766.000000
# mean   1.652016e+08  5.433040e+07           2.024006
# std    1.026403e+08  3.869636e+07           1.445403
# min    1.252200e+04  1.350000e+02           1.000000
# 25%    8.496119e+07  2.341322e+07           1.000000
# 50%    1.523890e+08  4.550514e+07           1.000000
# 75%    2.302709e+08  8.754595e+07           3.000000
# max    4.438672e+08  1.895026e+08           8.000000
#
#        discharge_disposition_id  admission_source_id  time_in_hospital  \
# count             101766.000000        101766.000000     101766.000000
# mean                   3.715642             5.754437          4.395987
# std                    5.280166             4.064081          2.985108
# min                    1.000000             1.000000          1.000000
# 25%                    1.000000             1.000000          2.000000
# ...

# %%
df.head()
# Out:
#    encounter_id  patient_nbr             race  gender      age weight  \
# 0       2278392      8222157        Caucasian  Female   [0-10)      ?
# 1        149190     55629189        Caucasian  Female  [10-20)      ?
# 2         64410     86047875  AfricanAmerican  Female  [20-30)      ?
# 3        500364     82442376        Caucasian    Male  [30-40)      ?
# 4         16680     42519267        Caucasian    Male  [40-50)      ?
#
#    admission_type_id  discharge_disposition_id  admission_source_id  \
# 0                  6                        25                    1
# 1                  1                         1                    7
# 2                  1                         1                    7
# 3                  1                         1                    7
# 4                  1                         1                    7
#
#    time_in_hospital  ... citoglipton insulin  glyburide-metformin  \
# ...

# %%
# Multiple occurrences of patient_number (30,248)

# %%
df['patient_nbr'].is_unique
# Out:
# False

# %%
df['patient_nbr'].nunique()
# Out:
# 71518

# %%
# Looking for null values and duplicates in the data

# %%
print(df.isnull().sum())
# Out:
# encounter_id                0
# patient_nbr                 0
# race                        0
# gender                      0
# age                         0
# weight                      0
# admission_type_id           0
# discharge_disposition_id    0
# admission_source_id         0
# time_in_hospital            0
# payer_code                  0
# medical_specialty           0
# num_lab_procedures          0
# num_procedures              0
# num_medications             0
# number_outpatient           0
# number_emergency            0
# number_inpatient            0
# diag_1                      0
# diag_2                      0
# diag_3                      0
# number_diagnoses            0
# max_glu_serum               0
# A1Cresult                   0
# metformin                   0
# repaglinide                 0
# nateglinide                 0
# chlorpropamide              0
# glimepiride                 0
# acetohexamide               0
# glipizide                   0
# ...

# %%
duplicate_rows_df = df[df.duplicated()]
print("number of duplicate rows: ", duplicate_rows_df.shape)
# Out:
# number of duplicate rows:  (0, 50)

# %%
# Drop columns that will not be used in the analysis

# %%
drop_cols1 = ['encounter_id','weight','admission_type_id','discharge_disposition_id','admission_source_id','time_in_hospital','readmitted']

# %%
drop_cols2 = ['payer_code','medical_specialty','num_lab_procedures','num_procedures','number_outpatient','number_emergency','number_inpatient','diag_3']

# %%
drop_cols3 = ['metformin','repaglinide','nateglinide','chlorpropamide','glimepiride','acetohexamide','glipizide','glyburide','tolbutamide','pioglitazone','rosiglitazone','acarbose','miglitol','troglitazone','tolazamide','examide','citoglipton','glyburide-metformin','glipizide-metformin','glimepiride-pioglitazone','metformin-rosiglitazone','metformin-pioglitazone']

# %%
df.drop(drop_cols3, inplace = True, axis=1)

# %%
df.drop(drop_cols2, inplace = True, axis=1)

# %%
df.drop(drop_cols1, inplace = True, axis=1)

# %%
df.head()
# Out:
#    patient_nbr             race  gender      age  num_medications  diag_1  \
# 0      8222157        Caucasian  Female   [0-10)                1  250.83
# 1     55629189        Caucasian  Female  [10-20)               18     276
# 2     86047875  AfricanAmerican  Female  [20-30)               13     648
# 3     82442376        Caucasian    Male  [30-40)               16       8
# 4     42519267        Caucasian    Male  [40-50)                8     197
#
#    diag_2  number_diagnoses max_glu_serum A1Cresult insulin change diabetesMed
# 0       ?                 1          None      None      No     No          No
# 1  250.01                 9          None      None      Up     Ch         Yes
# 2     250                 6          None      None      No     No         Yes
# 3  250.43                 7          None      None      Up     Ch         Yes
# 4     157                 5          None      None  Steady     Ch         Yes

# %%
df.tail()
# Out:
#         patient_nbr             race  gender      age  num_medications  \
# 101761    100162476  AfricanAmerican    Male  [70-80)               16
# 101762     74694222  AfricanAmerican  Female  [80-90)               18
# 101763     41088789        Caucasian    Male  [70-80)                9
# 101764     31693671        Caucasian  Female  [80-90)               21
# 101765    175429310        Caucasian    Male  [70-80)                3
#
#         diag_1 diag_2  number_diagnoses max_glu_serum A1Cresult insulin  \
# 101761  250.13    291                 9          None        >8    Down
# 101762     560    276                 9          None      None  Steady
# 101763      38    590                13          None      None    Down
# 101764     996    285                 9          None      None      Up
# 101765     530    530                 9          None      None      No
#
#        change diabetesMed
# 101761     Ch         Yes
# 101762     No         Yes
# ...

# %%
df.groupby(by='age')['number_diagnoses'].describe()
# Out:
#             count      mean       std  min  25%  50%  75%   max
# age
# [0-10)      161.0  2.695652  1.864281  1.0  1.0  2.0  3.0   9.0
# [10-20)     691.0  3.947902  2.265086  1.0  2.0  4.0  5.0   9.0
# [20-30)    1657.0  5.866626  2.328090  1.0  4.0  6.0  8.0  14.0
# [30-40)    3775.0  6.452980  2.223913  1.0  5.0  6.0  9.0  16.0
# [40-50)    9685.0  6.948787  2.070589  1.0  5.0  7.0  9.0  16.0
# [50-60)   17256.0  7.238584  1.964931  1.0  6.0  8.0  9.0  16.0
# [60-70)   22483.0  7.506427  1.862690  1.0  6.0  8.0  9.0  16.0
# [70-80)   26068.0  7.651795  1.764932  1.0  6.0  9.0  9.0  16.0
# [80-90)   17197.0  7.888702  1.635572  1.0  7.0  9.0  9.0  16.0
# [90-100)   2793.0  7.884712  1.614857  1.0  7.0  9.0  9.0  14.0

# %%
df.groupby(by='gender')['number_diagnoses'].describe()
# Out:
#                    count      mean       std  min  25%  50%  75%   max
# gender
# Female           54708.0  7.428639  1.923474  1.0  6.0  8.0  9.0  16.0
# Male             47055.0  7.415684  1.945255  1.0  6.0  8.0  9.0  16.0
# Unknown/Invalid      3.0  6.000000  2.645751  4.0  4.5  5.0  7.0   9.0

# %%
df.groupby(by='race')['number_diagnoses'].describe()
# Out:
#                    count      mean       std  min  25%  50%  75%   max
# race
# ?                 2273.0  6.695557  2.115016  1.0  5.0  7.0  9.0  16.0
# AfricanAmerican  19210.0  7.108381  2.022755  1.0  5.0  8.0  9.0  16.0
# Asian              641.0  7.049922  2.085816  1.0  5.0  8.0  9.0   9.0
# Caucasian        76099.0  7.544790  1.878179  1.0  6.0  9.0  9.0  16.0
# Hispanic          2037.0  6.924399  2.145764  1.0  5.0  7.0  9.0  16.0
# Other             1506.0  7.186587  2.031409  1.0  6.0  8.0  9.0   9.0

# %%
# Most common primary diagnosis (diag_1) in the data set is 428 (Heart failure) followed by
# other forms of chronic ischemic heart failure (414) and symptoms involving respiratory 
# system and other chest symptoms (786)

# %%
df['diag_1'].value_counts()
# Out:
# 428    6862
# 414    6581
# 786    4016
# 410    3614
# 486    3508
#        ...
# 219       1
# 375       1
# 988       1
# 57        1
# 903       1
# Name: diag_1, Length: 717, dtype: int64

# %%
# Most common secondary diagnosis (diag_2) in the data set is 276 (disorders of fluid 
# electrolyte and acid-base balance) followed by heart failure (428) and diabetes (250)

# %%
df['diag_2'].value_counts()
# Out:
# 276     6752
# 428     6662
# 250     6071
# 427     5036
# 401     3736
#         ...
# 353        1
# 52         1
# 123        1
# E818       1
# 137        1
# Name: diag_2, Length: 749, dtype: int64

# %%
# I decided to focus on data for individuals in the 60-70 year age range.

# %%
dfA = df[df['age']== '[60-70)']

# %%
# Explore other demographic measures associated with this population

# %%
dfA.groupby(by='gender')['num_medications'].describe()
# Out:
#                    count       mean       std  min   25%   50%   75%   max
# gender
# Female           11061.0  17.399060  8.385052  1.0  12.0  16.0  22.0  75.0
# Male             11421.0  16.910603  8.874873  1.0  11.0  15.0  21.0  81.0
# Unknown/Invalid      1.0   6.000000       NaN  6.0   6.0   6.0   6.0   6.0

# %%
dfA.groupby(by='race')['number_diagnoses'].describe()
# Out:
#                    count      mean       std  min  25%  50%  75%   max
# race
# ?                  495.0  6.852525  2.167217  2.0  5.0  7.0  9.0  16.0
# AfricanAmerican   4232.0  7.329159  1.907980  1.0  6.0  8.0  9.0  16.0
# Asian              160.0  7.000000  2.021893  2.0  5.0  7.0  9.0   9.0
# Caucasian        16693.0  7.585515  1.827139  1.0  6.0  9.0  9.0  16.0
# Hispanic           489.0  7.274029  1.970729  1.0  6.0  8.0  9.0  13.0
# Other              414.0  7.381643  1.897941  2.0  6.0  8.0  9.0   9.0

# %%
# Selected the female population for further analysis

# %%
dfG = dfA[dfA['gender']=='Female']

# %%
dfG.head()
# Out:
#     patient_nbr             race  gender      age  num_medications diag_1  \
# 14     49726791  AfricanAmerican  Female  [60-70)                2    518
# 30     56480238  AfricanAmerican  Female  [60-70)               18    584
# 35     63023292        Caucasian  Female  [60-70)               11    411
# 37    112002975        Caucasian  Female  [60-70)               12    486
# 54    113848434                ?  Female  [60-70)                4    618
#
#     diag_2  number_diagnoses max_glu_serum A1Cresult insulin change  \
# 14     998                 8          None      None  Steady     No
# 30     496                 9          None      None  Steady     Ch
# 35  250.01                 6          None      None    Down     Ch
# 37     244                 3          None      None  Steady     Ch
# 54     997                 9          None      None    Down     Ch
#
#    diabetesMed
# 14         Yes
# 30         Yes
# 35         Yes
# 37         Yes
# 54         Yes

# %%
# Mean number of medications (17) and diagnoses (7) for women in the 60-70 age range

# %%
dfG.describe()
# Out:
#         patient_nbr  num_medications  number_diagnoses
# count  1.106100e+04     11061.000000      11061.000000
# mean   5.378547e+07        17.399060          7.511708
# std    3.847184e+07         8.385052          1.854610
# min    1.152000e+03         1.000000          1.000000
# 25%    2.335349e+07        12.000000          6.000000
# 50%    4.491536e+07        16.000000          8.000000
# 75%    8.640470e+07        22.000000          9.000000
# max    1.892989e+08        75.000000         16.000000

# %%
# Group by race
# Highest number of diagnoses and medications taken are for Caucasians,
# followed by African Americans

# %%
dfG.groupby(by='race')['number_diagnoses'].mean().plot(kind="bar")

# %%
dfG.groupby(by='race')['num_medications'].mean().plot(kind="bar")

# %%
# Top 3 Diagnoses

# %%
# Most common primary diagnosis (diag_1) for women aged 60-70 is 414 (Other forms of chronic 
# ischemic heart disease followed by heart failure(428) and symptoms involving respiratory
# system and other chest symptoms (786)

# %%
dfG['diag_1'].value_counts()
# Out:
# 414    767
# 428    706
# 786    499
# 715    422
# 486    348
#       ...
# 579      1
# 890      1
# 322      1
# 914      1
# 866      1
# Name: diag_1, Length: 429, dtype: int64

# %%
# Most common secondary diagnosis (diag_2) for women aged 60-70 is 428 (heart failure) followed
# by diabetes(250) and disorders of fluid electrolyte and acid-base balance (276)

# %%
dfG['diag_2'].value_counts()
# Out:
# 428     745
# 250     743
# 276     606
# 401     477
# 427     405
#        ...
# E906      1
# E812      1
# 457       1
# 495       1
# 513       1
# Name: diag_2, Length: 439, dtype: int64

# %%
dfX = dfG[dfG['diag_1']=='414']

# %%
# What is the mean number of medications that a 60-70 year old women with (other) chronic
# ischemic heart disease takes? 21

# What is the mean number of diagnoses that a 60-70 year old woman with (other)chronic 
# ischemic heart disease has? 7

# %%
# Most common secondary diagnosis within the primary diagnosis category
# 411 - Other acute and subacute forms of ischemic heart disease
# 413 - Angina pectoris
# 250 - Diabetes mellitus

# %%
dfX['diag_2'].value_counts()
# Out:
# 411       241
# 413       102
# 250        52
# 428        48
# 401        37
#          ...
# 255         1
# 250.82      1
# 512         1
# 394         1
# 242         1
# Name: diag_2, Length: 70, dtype: int64
